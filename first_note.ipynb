# %% [markdown]
# <a href="https://colab.research.google.com/github/Hajinhw/Python/blob/main/first_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 코랩 시작하기

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.25.2'

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0,5, 0.2)
y1 = x **2
y2 = x **3

# %%
plt.plot(x, y1, label='x**2')
plt.plot(x, y2, label='x**3')
plt.legend()
plt.show()
